# %%
from pymilvus import MilvusClient
from pymilvus import model
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[10], line 2
#       1 from pymilvus import MilvusClient
# ----> 2 from pymilvus import model
#       3 import numpy as np
#
# ImportError: cannot import name 'model' from 'pymilvus' (a:\programmers\anaconda3\Lib\site-packages\pymilvus\__init__.py)

# %%
# !pip install "pymilvus[model]"
# Out:
# Requirement already satisfied: pymilvus[model] in a:\programmers\anaconda3\lib\site-packages (2.6.5)
# Requirement already satisfied: setuptools>69 in a:\programmers\anaconda3\lib\site-packages (from pymilvus[model]) (80.9.0)
# Requirement already satisfied: grpcio!=1.68.0,!=1.68.1,!=1.69.0,!=1.70.0,!=1.70.1,!=1.71.0,!=1.72.1,!=1.73.0,>=1.66.2 in a:\programmers\anaconda3\lib\site-packages (from pymilvus[model]) (1.76.0)
# Requirement already satisfied: orjson>=3.10.15 in a:\programmers\anaconda3\lib\site-packages (from pymilvus[model]) (3.11.5)
# Requirement already satisfied: protobuf>=5.27.2 in a:\programmers\anaconda3\lib\site-packages (from pymilvus[model]) (6.33.2)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.1 in a:\programmers\anaconda3\lib\site-packages (from pymilvus[model]) (1.2.1)
# Requirement already satisfied: pandas>=1.2.4 in a:\programmers\anaconda3\lib\site-packages (from pymilvus[model]) (2.3.3)
# Collecting pymilvus.model>=0.3.0 (from pymilvus[model])
#   Downloading pymilvus_model-0.3.2-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: typing-extensions~=4.12 in a:\programmers\anaconda3\lib\site-packages (from grpcio!=1.68.0,!=1.68.1,!=1.69.0,!=1.70.0,!=1.70.1,!=1.71.0,!=1.72.1,!=1.73.0,>=1.66.2->pymilvus[model]) (4.15.0)
# Requirement already satisfied: numpy>=1.26.0 in a:\programmers\anaconda3\lib\site-packages (from pandas>=1.2.4->pymilvus[model]) (2.4.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in a:\programmers\anaconda3\lib\site-packages (from pandas>=1.2.4->pymilvus[model]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in a:\programmers\anaconda3\lib\site-packages (from pandas>=1.2.4->pymilvus[model]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in a:\programmers\anaconda3\lib\site-packages (from pandas>=1.2.4->pymilvus[model]) (2025.3)
# Requirement already satisfied: transformers>=4.36.0 in a:\programmers\anaconda3\lib\site-packages (from pymilvus.model>=0.3.0->pymilvus[model]) (4.56.2)
# Collecting onnxruntime (from pymilvus.model>=0.3.0->pymilvus[model])
#   Downloading onnxruntime-1.23.2-cp313-cp313-win_amd64.whl.metadata (5.3 kB)
# Requirement already satisfied: scipy>=1.10.0 in a:\programmers\anaconda3\lib\site-packages (from pymilvus.model>=0.3.0->pymilvus[model]) (1.15.3)
# Requirement already satisfied: six>=1.5 in a:\programmers\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.2.4->pymilvus[model]) (1.17.0)
# Requirement already satisfied: filelock in a:\programmers\anaconda3\lib\site-packages (from transformers>=4.36.0->pymilvus.model>=0.3.0->pymilvus[model]) (3.17.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in a:\programmers\anaconda3\lib\site-packages (from transformers>=4.36.0->pymilvus.model>=0.3.0->pymilvus[model]) (0.35.1)
# Requirement already satisfied: packaging>=20.0 in a:\programmers\anaconda3\lib\site-packages (from transformers>=4.36.0->pymilvus.model>=0.3.0->pymilvus[model]) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in a:\programmers\anaconda3\lib\site-packages (from transformers>=4.36.0->pymilvus.model>=0.3.0->pymilvus[model]) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in a:\programmers\anaconda3\lib\site-packages (from transformers>=4.36.0->pymilvus.model>=0.3.0->pymilvus[model]) (2024.11.6)
# Requirement already satisfied: requests in a:\programmers\anaconda3\lib\site-packages (from transformers>=4.36.0->pymilvus.model>=0.3.0->pymilvus[model]) (2.32.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in a:\programmers\anaconda3\lib\site-packages (from transformers>=4.36.0->pymilvus.model>=0.3.0->pymilvus[model]) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in a:\programmers\anaconda3\lib\site-packages (from transformers>=4.36.0->pymilvus.model>=0.3.0->pymilvus[model]) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in a:\programmers\anaconda3\lib\site-packages (from transformers>=4.36.0->pymilvus.model>=0.3.0->pymilvus[model]) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in a:\programmers\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.34.0->transformers>=4.36.0->pymilvus.model>=0.3.0->pymilvus[model]) (2024.6.1)
# Requirement already satisfied: colorama in a:\programmers\anaconda3\lib\site-packages (from tqdm>=4.27->transformers>=4.36.0->pymilvus.model>=0.3.0->pymilvus[model]) (0.4.6)
# Collecting coloredlogs (from onnxruntime->pymilvus.model>=0.3.0->pymilvus[model])
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in a:\programmers\anaconda3\lib\site-packages (from onnxruntime->pymilvus.model>=0.3.0->pymilvus[model]) (25.9.23)
# Requirement already satisfied: sympy in a:\programmers\anaconda3\lib\site-packages (from onnxruntime->pymilvus.model>=0.3.0->pymilvus[model]) (1.13.3)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime->pymilvus.model>=0.3.0->pymilvus[model])
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: pyreadline3 in a:\programmers\anaconda3\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime->pymilvus.model>=0.3.0->pymilvus[model]) (3.5.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in a:\programmers\anaconda3\lib\site-packages (from requests->transformers>=4.36.0->pymilvus.model>=0.3.0->pymilvus[model]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in a:\programmers\anaconda3\lib\site-packages (from requests->transformers>=4.36.0->pymilvus.model>=0.3.0->pymilvus[model]) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in a:\programmers\anaconda3\lib\site-packages (from requests->transformers>=4.36.0->pymilvus.model>=0.3.0->pymilvus[model]) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in a:\programmers\anaconda3\lib\site-packages (from requests->transformers>=4.36.0->pymilvus.model>=0.3.0->pymilvus[model]) (2025.10.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in a:\programmers\anaconda3\lib\site-packages (from sympy->onnxruntime->pymilvus.model>=0.3.0->pymilvus[model]) (1.3.0)
# Downloading pymilvus_model-0.3.2-py3-none-any.whl (47 kB)
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProxyError('Cannot connect to proxy.', TimeoutError('_ssl.c:1011: The handshake operation timed out'))': /simple/pymilvus-model/
# WARNING: Connection timed out while downloading.
# ERROR: Could not install packages due to an OSError: [WinError 32] 另一个程序正在使用此文件，进程无法访问。: 'C:\\Users\\raymo\\AppData\\Local\\Temp\\pip-unpack-knogk2ci\\pymilvus_model-0.3.2-py3-none-any.whl'
# Consider using the `--user` option or check the permissions.

# %%
if client.has_collection(collection_name="demo_collection"):
    client.drop_collection(collection_name="demo_collection")
client.create_collection(
    collection_name="demo_collection",
    dimension=768,  # The vectors we will use in this demo has 768 dimensions
)

# %%
# This will download a small embedding model "paraphrase-albert-small-v2" (~50MB).
embedding_fn = model.DefaultEmbeddingFunction()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 # This will download a small embedding model "paraphrase-albert-small-v2" (~50MB).
# ----> 2 embedding_fn = model.DefaultEmbeddingFunction()
#
# NameError: name 'model' is not defined
